# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
import preprocessor as p
import csv, string
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-f6b8dddeaa1f> in <module>()
#       1 import pandas as pd
# ----> 2 from sklearn.model_selection import GridSearchCV
#       3 import preprocessor as p
#       4 import csv, string
#
# ImportError: No module named 'sklearn.model_selection'

# %%
df_train = pd.read_csv('trainingandtestdata/training.1600000.processed.noemoticon.csv', encoding = "ISO-8859-1", names =["Class", "ID", "Date", "ToBeDeleted","Name", "UnprocessedText"])
df_test = pd.read_csv('trainingandtestdata/testdata.manual.2009.06.14.csv', encoding = "ISO-8859-1", names =["Class","Some", "ID", "Date", "ToBeDeleted", "UnprocessedText"])
df_train.drop(['ID', 'Date', 'ToBeDeleted', 'Name'], axis=1, inplace=True)
df_test.drop(['Some','ID', 'Date', 'ToBeDeleted'], axis=1, inplace=True)

# %%
def clean(df,cleaned_file_path):
    with open(cleaned_file_path, 'w') as cleanedDatacsvfile:
        cleanedDatawriter = csv.writer(cleanedDatacsvfile)
        for r in df['UnprocessedText']:
            #polarity = r[0].encode('utf-8', errors='replace')
            #running into problem in this line with encoding, tried utf-8 and latin-1
            cleanedText = p.clean(r).encode('utf-8', errors='replace')
            row = [cleanedText]
            cleanedDatawriter.writerow(row)

def remove_punctuation(s):
    s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
    return s

clean(df_train, 'trainingandtestdata/train_preprocessed.csv')
clean(df_test, 'trainingandtestdata/test_preprocessed.csv')

# %%
#df_train_preprocessed = pd.read_csv('trainingandtestdata/train_preprocessed.csv', encoding = "ISO-8859-1", names=['text'])
#df_train_preprocessed

#df_test_preprocessed = pd.read_csv('trainingandtestdata/test_preprocessed.csv', encoding="ISO-8859-1", names=['text'])
#df_test_preprocessed
# Out:
#                                                   text
# 0    b'I loooooooovvvvvveee my Kindle2. Not that th...
# 1    b'Reading my kindle2... Love it... Lee childs ...
# 2    b'Ok, first assesment of the ...it fucking roc...
# 3    b"You'll love your Kindle2. I've had mine for ...
# 4    b"Fair enough. But i have the Kindle2 and I th...
# 5    b"no. it is too big. I'm quite happy with the ...
# 6    b'Fuck this economy. I hate aig and their non ...
# 7                     b'Jquery is my new best friend.'
# 8                                     b'Loves twitter'
# 9    b'how can you not love Obama? he makes jokes a...
# 10   b"Check this video out -- President Obama at t...
# 11   b"I firmly believe that Obama/Pelosi have ZERO...
# 12   b'House Correspondents dinner was last night w...
# 13   b'Watchin Espn..Jus seen this new Nike Commeri...
# 14   b'dear nike, stop with the flywire. that shit ...
# 15   b"best athlete of our generation, if not all t...
# 16   b'I was talking to this guy last night and he ...
# 17                                   b'i love lebron.'
# 18   b"Lebron is a Beast, but I'm still cheering th...
# 19                               b'lebron IS THE BOSS'
# 20   b"Lebron is a hometown hero to me, lol I love ...
# 21      b'lebron and zydrunas are such an awesome duo'
# 22   b'Lebron is a beast... nobody in the NBA comes...
# 23   b'downloading apps for my iphone! So much fun ...
# 24   b'good news, just had a call from the Visa off...
# 25                  b'- awesome come back from (via )'
# 26   b'In montreal for a long weekend of R&amp;R. M...
# 27   b'Booz Allen Hamilton has a bad ass homegrown ...
# 28   b'[] Customer Innovation Award Winner: Booz Al...
# 29   b'I current use the Nikon D90 and love it, but...
# ..                                                 ...
# 468  b'Man I kinda dislike Apple right now. Case in...
# 469  b'I have a Kindle2 (&amp; Sony PRS-500). Like ...
# 470  b'The seems the best eReader, but will it work...
# 471  b'I have a google addiction. Thank you for poi...
# 472         b'My primary debit card is Visa Electron.'
# 473  b'Off to the bank to get my new visa platinum ...
# 474  b"dearest , you rich bastards! the VISA card y...
# 475  b'has a date with bobby flay and gut fieri fro...
# 476  b'Excited about seeing Bobby Flay and Guy Fier...
# 477  b'Gonna go see Bobby Flay moro at Shoreline. E...
# 478  b"can't wait for the great american food and m...
# 479  b'My dad was in NY for a day, we ate at MESA g...
# 480                   b'Fighting with LaTex. Again...'
# 481  b"we love you too and don't want you to die!!!...
# 482  b"hours. hours of inkscape crashing, normally ...
# 483            b'How to Track Iran with Social Media:'
# 484  b"Shit's hitting the fan in Iran...craziness i...
# 485  b'Monday already. Iran may implode. Kitchen is...
# 486  b'Twitter Stock buzz: $AAPL $ES_F $SPY $SPX $P...
# 487  b'getting ready to test out some burger receip...
# 488                      b'is Bobby Flay joining you?'
# 489  b'i lam so in love with Bobby Flay... he is my...
# 490  b"I just created my first LaTeX file from scra...
# 491  b'using Linux and loving it - so much nicer th...
# 492  b'After using LaTeX a lot, any other typeset m...
# 493  b'Ask Programming: LaTeX or InDesign?: submitt...
# 494  b'On that note, I hate Word. I hate Pages. I h...
# 495  b'Ahhh... back in a *real* text editing enviro...
# 496  b'Trouble in Iran, I see. Hmm. Iran. Iran so f...
# 497  b'Reading the tweets coming out of Iran... The...
#
# [498 rows x 1 columns]

# %%
# del df_train_preprocessed['random']
#df_train_preprocessed['text'] = df_train_preprocessed['text'].map(lambda x: x.lstrip('b'))
#df_train_preprocessed['text'] = df_train_preprocessed['text'].apply(remove_punctuation)
# #df_test
# #df_test_preprocessed
#df_train = pd.concat([df_train, df_train_preprocessed], axis=1)

df_test_preprocessed = pd.read_csv('trainingandtestdata/test_preprocessed.csv', encoding = "ISO-8859-1", names=['text'])
# del df_test_preprocessed['random']
df_test_preprocessed['text'] = df_test_preprocessed['text'].map(lambda x: x.lstrip('b'))
df_test_preprocessed['text'] = df_test_preprocessed['text'].apply(remove_punctuation)
# #df_test
# #df_test_preprocessed
df_test = pd.concat([df_test, df_test_preprocessed], axis=1)

# del df_test['Some']
# del df_test['ID']
# del df_test['Date']
# del df_test['ToBeDeleted']

# %%
df_train[df_train["Class"]==4]
# Out:
#          Class                                    UnprocessedText  \
# 800000       4       I LOVE @Health4UandPets u guys r the best!!
# 800001       4  im meeting up with one of my besties tonight! ...
# 800002       4  @DaRealSunisaKim Thanks for the Twitter add, S...
# 800003       4  Being sick can be really cheap when it hurts t...
# 800004       4    @LovesBrooklyn2 he has that effect on everyone
#
# [800000 rows x 3 columns]

# %%
import pandas as pd
#df_train.to_csv("finalprocessing.csv")
#df_test.to_csv("finalprocessing_test.csv")

df_train = pd.read_csv('finalprocessing.csv', encoding='ISO-8859-1')
df_test = pd.read_csv('finalprocessing_test.csv', encoding='ISO-8859-1')

df_train = df_train[df_train.text.notnull()]
df_train
# Out:
#          Unnamed: 0  Class                                    UnprocessedText  \
# 0                 0      0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1                 1      0  is upset that he can't update his Facebook by ...
# 2                 2      0  @Kenichan I dived many times for the ball. Man...
# 3                 3      0    my whole body feels itchy and like its on fire
# 4                 4      0  @nationwideclass no, it's not behaving at all....
# 5                 5      0                      @Kwesidei not the whole crew
# 6                 6      0                                        Need a hug
# 7                 7      0  @LOLTrish hey  long time no see! Yes.. Rains a...
# 8                 8      0               @Tatiana_K nope they didn't have it
# 9                 9      0                          @twittera que me muera ?
# 10               10      0        spring break in plain city... it's snowing
# 11               11      0                         I just re-pierced my ears
# 12               12      0  @caregiving I couldn't bear to watch it.  And ...
# 13               13      0  @octolinz16 It it counts, idk why I did either...
# 14               14      0  @smarrison i would've been the first, but i di...
# 15               15      0  @iamjazzyfizzle I wish I got to watch it with ...
# 16               16      0  Hollis' death scene will hurt me severely to w...
# 17               17      0                               about to file taxes
# 18               18      0  @LettyA ahh ive always wanted to see rent  lov...
# 19               19      0  @FakerPattyPattz Oh dear. Were you drinking ou...
# 20               20      0  @alydesigns i was out most of the day so didn'...
# 21               21      0  one of my friend called me, and asked to meet ...
# 22               22      0   @angry_barista I baked you a cake but I ated it
# 23               23      0             this week is not going as i had hoped
# 24               24      0                         blagh class at 8 tomorrow
# 25               25      0     I hate when I have to call and wake people up
# 26               26      0  Just going to cry myself to sleep after watchi...
# 27               27      0                             im sad now  Miss.Lilly
# 28               28      0  ooooh.... LOL  that leslie.... and ok I won't ...
# 29               29      0  Meh... Almost Lover is the exception... this t...
# ...             ...    ...                                                ...
# 1599969     1599969      4  @davepell you're the undisputed authority on t...
# 1599970     1599970      4  Thanks @eastwestchic &amp; @wangyip Thanks! Th...
# 1599971     1599971      4  @marttn thanks Martin. not the most imaginativ...
# 1599972     1599972      4          @MikeJonesPhoto Congrats Mike  Way to go!
# 1599973     1599973      4  http://twitpic.com/7jp4n - OMG! Office Space.....
# 1599974     1599974      4  @yrclndstnlvr ahaha nooo you were just away fr...
# 1599975     1599975      4  @BizCoachDeb  Hey, I'm baack! And, thanks so m...
# 1599976     1599976      4  @mattycus Yeah, my conscience would be clear i...
# 1599977     1599977      4  @MayorDorisWolfe Thats my girl - dishing out t...
# 1599978     1599978      4                          @shebbs123 i second that
# 1599979     1599979      4                                     In the garden
# 1599980     1599980      4  @myheartandmind jo jen by nemuselo zrovna tÃÂ...
# 1599981     1599981      4  Another Commenting Contest! [;: Yay!!!  http:/...
# 1599982     1599982      4  @thrillmesoon i figured out how to see my twee...
# 1599985  if ur the lead singer in a band beware falling...
# 1599986                            too much ads on my blog
# 1599987  NEVEER I think that you both will get on well ...
# 1599988  ha good job thats right  we gotta throw that t...
# 1599989                              im glad ur doing well
# 1599990                                WOOOOO Xbox is back
# 1599991  Mmmm That sounds absolutely perfect but my sch...
# 1599992                   ReCoVeRiNg FrOm ThE lOnG wEeKeNd
# 1599994  Yeah that does work better than just waiting f...
# 1599995  Just woke up Having no school is the best feel...
# 1599996  TheWDBcom  Very cool to hear old Walt intervie...
# 1599997  Are you ready for your MoJo Makeover Ask me fo...
# 1599998  Happy th Birthday to my boo of alll time Tupac...
# 1599999                                              happy
#
# [1596728 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vect = CountVectorizer(stop_words='english', lowercase=True)
X_train_counts = count_vect.fit_transform(df_train['text'])
X_train_counts.shape
# Out:
# (1596728, 431353)

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (1596728, 431353)

# %%
from sklearn.naive_bayes import MultinomialNB
from numpy import array
import numpy as np

df_list = array(df_train['Class'].tolist())
df_list

#x= np.random.randint(5, size=(6,100))
#y = np.array([1,2,3,4,5,6])

# dflist = df_train['Class'].tolist()
# df_final = df_train.as_matrix(columns=['Class'])
# X_train_tfidf
clf = MultinomialNB()
clf.fit(X_train_tfidf,df_list)



#print (clf.predict(x[2:3]))
#dflist
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
test_text = df_test['text'][0]
testing = [test_text]
X_new_counts = count_vect.transform(testing)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = clf.predict(X_new_tfidf)

# %%
predicted
# Out:
# array([4])

# %%
from sklearn.pipeline import Pipeline

text_clf = Pipeline ([('vect', CountVectorizer()), ('tfidf', TfidfTransformer()), ('clf', MultinomialNB()),])
text_clf = text_clf.fit(df_train['text'], df_list)

# %%
predicted = text_clf.predict(df_test['text'])

# %%
df_test_list = array(df_test['Class'].tolist())
np.mean(predicted ==  df_test_list)
# Out:
# 0.80779944289693595

# %%
df_test = df_test[df_test.Class != 2]

# %%
df_test
# Out:
#      Unnamed: 0  Class                                    UnprocessedText  \
# 0             0      4  @stellargirl I loooooooovvvvvveee my Kindle2. ...
# 1             1      4  Reading my kindle2...  Love it... Lee childs i...
# 2             2      4  Ok, first assesment of the #kindle2 ...it fuck...
# 3             3      4  @kenburbary You'll love your Kindle2. I've had...
# 4             4      4  @mikefish  Fair enough. But i have the Kindle2...
# 5             5      4  @richardebaker no. it is too big. I'm quite ha...
# 6             6      0  Fuck this economy. I hate aig and their non lo...
# 7             7      4                      Jquery is my new best friend.
# 8             8      4                                      Loves twitter
# 9             9      4  how can you not love Obama? he makes jokes abo...
# 11           11      0  @Karoli I firmly believe that Obama/Pelosi hav...
# 12           12      4  House Correspondents dinner was last night who...
# 13           13      4  Watchin Espn..Jus seen this new Nike Commerica...
# 4    Fair enough But i have the Kindle2 and I think...
# 5     no it is too big Im quite happy with the Kindle2
# 6    Fuck this economy I hate aig and their non loa...
# 7                         Jquery is my new best friend
# 8                                        Loves twitter
# 9    how can you not love Obama he makes jokes abou...
# 11   I firmly believe that ObamaPelosi have ZERO de...
# 12   House Correspondents dinner was last night who...
# 13   Watchin EspnJus seen this new Nike Commerical ...
# 14   dear nike stop with the flywire that shit is a...
# 15   best athlete of our generation if not all time...
# 16   I was talking to this guy last night and he wa...
# 17                                       i love lebron
# 18   Lebron is a Beast but Im still cheering the At...
# 19                                  lebron IS THE BOSS
# 20   Lebron is a hometown hero to me lol I love the...
# 21         lebron and zydrunas are such an awesome duo
# 22   Lebron is a beast nobody in the NBA comes even...
# 23   downloading apps for my iphone So much fun The...
# 24   good news just had a call from the Visa office...
# 25                         awesome come back from via
# 26   In montreal for a long weekend of RampR Much n...
# 27   Booz Allen Hamilton has a bad ass homegrown so...
# 28    Customer Innovation Award Winner Booz Allen H...
# 29   I current use the Nikon D90 and love it but no...
# 32   Google is always a good place to look Shouldve...
# ..                                                 ...
# 457  Although todays keynote rocked for every great...
# 458   its not so much my obsession with cell phones...
# 461                   Fuzzball is more fun than ATampT
# 462  Today is a good day to dislike ATampT Vote out...
# 463  GOT MY WAVE SANDBOX INVITE Extra excited Too b...
# 464  looks like summize has gone down too many twee...
# 467  Thanks so much from one of your very happy Kin...
# 468  Man I kinda dislike Apple right now Case in po...
# 469  I have a Kindle2 amp Sony PRS500 Like it Physi...
# 470  The seems the best eReader but will it work in...
# 471  I have a google addiction Thank you for pointi...
# 474  dearest  you rich bastards the VISA card you s...
# 476  Excited about seeing Bobby Flay and Guy Fieri ...
# 477  Gonna go see Bobby Flay moro at Shoreline Eat ...
# 478  cant wait for the great american food and musi...
# 479  My dad was in NY for a day we ate at MESA gril...
# 480                          Fighting with LaTex Again
# 481  we love you too and dont want you to die Latex...
# 482  hours hours of inkscape crashing normally soli...
# 484      Shits hitting the fan in Irancraziness indeed
# 485  Monday already Iran may implode Kitchen is a d...
# 487  getting ready to test out some burger receipes...
# 489  i lam so in love with Bobby Flay he is my favo...
# 490  I just created my first LaTeX file from scratc...
# 491  using Linux and loving it  so much nicer than ...
# 492  After using LaTeX a lot any other typeset math...
# 494  On that note I hate Word I hate Pages I hate L...
# 495  Ahhh back in a real text editing environment I...
# 496    Trouble in Iran I see Hmm Iran Iran so far away
# 497  Reading the tweets coming out of Iran The whol...
#
# [359 rows x 4 columns]

# %%
from sklearn.linear_model import SGDClassifier

text_clf = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer()),
                     ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-2, n_iter=10, random_state=42)),
                    ])

text_clf = text_clf.fit(df_train['text'], df_list)

# %%
predicted = text_clf.predict(df_test['text'])
df_test_list = array(df_test['Class'].tolist())
np.mean(predicted ==  df_test_list)
# Out:
# 0.56545961002785516
